# %% [markdown]
# <a href="https://colab.research.google.com/github/arvyz/privacynlu/blob/main/qa_data_aug_looser.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers --quiet
# !pip install torch --quiet
# !pip install accelerate --quiet
# !pip install datasets --quiet
# !pip install huggingface_hub --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.4/297.4 kB 6.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 10.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 12.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 18.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 13.4 MB/s eta 0:00:00

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Token:
# Add token as git credential? (Y/n) n
# Token is valid (permission: write).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
from transformers import AutoTokenizer, pipeline
import transformers
import torch
from huggingface_hub import HfApi

# %%
import pandas as pd
from datasets import Dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Load Train & Test Data For Sentence Simplification
#
# Training data from the privacy policies will be loaded and the privacy sentences will be "rewritten" for simplification.  Since each question in the QA set are mapped against all the sentences, there are many repeats of the same sentences across the dataset.  So we will only "rewrite" unique sentences and then map the newly generated senteces back to the QA set.
#
# ## Size
# The full training corpus contains 3411 uniqe sentences (some sentences repeat across policies).
#
# The full testing corpus is 1231 unique sentences (some sentences repeat across policies).

# %%
file_path = '/content/drive/My Drive/w266-personal/Final Project/PLUE/data/privacyqa/policy_train_data.csv'

# Load the CSV file
df_train = pd.read_csv(file_path, sep='\t')  # Adjust the path and separator based on your file

# Extract unique segments and create a Dataset
# We will also only look at unique sentences since they are repeated for each question.
unique_segments_df_full = pd.DataFrame({'Segment': df_train['Segment'].unique()})

# %%
file_path = '/content/drive/My Drive/w266-personal/Final Project/PLUE/data/privacyqa/policy_test_data.csv'

# Load the CSV file
df_test = pd.read_csv(file_path, sep='\t')  # Adjust the path and separator based on your file

# Extract unique segments and create a Dataset
# We will also only look at unique sentences since they are repeated for each question.
unique_segments_df_test = pd.DataFrame({'Segment': df_test['Segment'].unique()})

# %%
display(unique_segments_df_full.shape)
display(unique_segments_df_full.head())
display(unique_segments_df_test.shape)
display(unique_segments_df_test.head())
# Out:
# (3411, 1)
#                                              Segment
# 0   This privacy policy, with our Terms of Servic...
# 1  We encourage you to read this privacy policy c...
# 2  By using our application or other online servi...
# 3   When we post changes to this privacy policy, ...
# 4  We encourage you to review this privacy policy...
# (1231, 1)
#                                              Segment
# 0              At Fiverr we care about your privacy.
# 1  We do not sell or rent your personal informati...
# 2  We do not disclose it to others except as disc...
# 3    We collect information that you provide us o...
# 4    We will not share information that you provi...

# %% [markdown]
# ## Sampling Process for getting heuristic parameters
# We will look at a smaller "sample" of sentences (n=200) to defined the heuristic weights for the "rewriting" process.  The smaller set is sampled across all the polcies to get a wide variety of sentences etc to be able to valdate the data prep process and appropriate prompts for the final "rewriting"

# %%
# Let's first experiment on a few 100 sentences
sample = 200
unique_segments_df_sample = unique_segments_df_full.sample(n=sample)
display(unique_segments_df_sample.shape)
display(unique_segments_df_sample.head())
# Out:
# (200, 1)
#                                                 Segment
# 480   Any information that you post in these locatio...
# 2912                   Provide personalized experiences
# 2833  When you provide your information to Epic as p...
# 604   Our name is an acronym for the Latin         p...
# 88    If you do not agree to the changes, you should...

# %% [markdown]
# # Prompt Engineering
#
# To simplify each of the sentences of the privacy policy, we will use a Large Language Model (LLM) to generate the ouput.  The model we will be using is Meta's LLAMA2 7B model that has been fine tuned for "Chat" contexts to be able to take a chat prompt and produce a reponses.
#
# ## Prompt Attempts
# LLMs are sensitve to prompts for generating appropriate text.  So it is important to test out various prompts to the drive the right type of reponse from the LLM.
#
# The following prompts were tested.  The final prompt chosed in bolded:
#
# 1.   rephrase and simplify this sentence for clarity for an average user:
# 2.   Rephrase and simplify the following sentence for clarity for an average user and do not add any qualifiying statements to the response.
# 3.   **Rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE:**
# 4.  Rephrase and simplify for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE:
# 5. Rephrase, simplify, and clarify for an average user; do not add any qualifiying statements to the response.  SENTENCE:
#
# A few additional other prompts were tested, but they did not work at all.  So I have excluded it from the data
#
# ## Prompt Selection Process
#
# Sample "rewritten" data was generated for all the above prompts and the final prompt for the QA experiment was selected based on visual inspection of results to ensure the generated text reasonably and faithfully represented the underlying intent of the sentence.  ***NOTE:*** This was not done by a privacy experty by the Research principle in consultation with another lay-person.  I had to balance between some really great simplifications, but some really awkward hallucinations  See below for two different sets of such responses.

# %% [markdown]
# |                              | Sample Prompt & Responses 1                          | Sample Prompt & Responses 2                           |
# |------------------------------|------------------------------------------------------|-------------------------------------------------------|
# | **Original Sentence:**      | When You Give Consent                                | Web Behavior Data                                     |
# |                              | We may share information about you with other       |                                                       |
# |                              | companies if you give us permission or direct us   |                                                       |
# |                              | to share the information.                            |                                                       |
# | **Prompt 1 Response:**      | Answer: When you give permission, we may share      | *There was no response*                               |
# |                              | information about you with other companies.         |                                                       |
# | **Prompt 3 Response:**      | REPHRASED SENTENCE: We may share information       | Rephrased and simplified sentence: Data on how        |
# |                              | about you with other companies if you give us       | people use the web.                                   |
# |                              | permission or direct us to do so.                   |                                                       |
# | **Prompt 4 Response:**      | REPHRASED SENTENCE: When you give permission,      | Web Behavior Data refers to the information          |
# |                              | we may share information about you with other      | collected about a user's online activities,          |
# |                              | companies.                                           | including their browsing history, search queries,    |
# |                              |                                                      | and interactions with websites and apps. This data   |
# |                              |                                                      | can be used to create a detailed profile of the     |
# |                              |                                                      | user's online behavior, which can be used to        |
# |                              |                                                      | personalize their online experience, improve the    |
# |                              |                                                      | effectiveness of online advertising, and enhance    |
# |                              |                                                      | the overall user experience.                         |
# | **Prompt 5 Response:**      | REPHRASED SENTENCE: If you agree, we can share     | Web Behavior Data refers to the information          |
# |                              | information about you with other companies.         | collected about a user's online activities,          |
# |                              |                                                      | including their browsing history, search queries,    |
# |                              |                                                      | and interactions with websites and applications.    |
# |                              |                                                      | This data can be used to create a detailed profile |
# |                              |                                                      | of the user's online behavior, which can be used to|
# |                              |                                                      | personalize their online experience, improve the    |
# |                              |                                                      | effectiveness of online advertising, and enhance    |
# |                              |                                                      | the overall user experience.                         |

# %%
# Function to add prompts to each segment
def add_prompts_4(row):
    prompt = f"Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: {row['Segment']}\n"
    return {"Prompt": prompt}

# Let's use a common variable name to help with code replication
dataset_4 = Dataset.from_pandas(unique_segments_df_sample)
# Apply function to create prompts
dataset_4 = dataset_4.map(add_prompts_4)
# Out:
# Map:   0%|          | 0/200 [00:00<?, ? examples/s]

# %%
# Based on Trail 4; Simple prompt; Higher Temperature

# Function to add prompts to each segment
def add_prompts_full(row):
    prompt = f"Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: {row['Segment']}\n"
    return {"Prompt": prompt}

# Let's use a common variable name to help with code replication
dataset_full = Dataset.from_pandas(unique_segments_df_full)
# Apply function to create prompts
dataset_full = dataset_full.map(add_prompts_full)
# Out:
# Map:   0%|          | 0/3411 [00:00<?, ? examples/s]

# %%
# Based on Trail 4; Simple prompt; Higher Temperature
# Let's do the same treatment for the Test sentences as we did for the training sentences
dataset_full_test = Dataset.from_pandas(unique_segments_df_test)

# Apply function to create prompts
dataset_full_test = dataset_full_test.map(add_prompts_full)
# Out:
# Map:   0%|          | 0/1231 [00:00<?, ? examples/s]

# %%
print("Dataset 4: ", dataset_4[0]['Prompt'])
print("Dataset Full Train: ", dataset_full[0]['Prompt'])
print("Dataset Full Test: ", dataset_full_test[0]['Prompt'])
# Out:
# Dataset 4:  Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: Any information that you post in these locations, or in our user forum, can be read, collected, and used by anyone and could enable others to send you unsolicited messages.
#
# Dataset Full Train:  Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE:  This privacy policy, with our Terms of Service & License Agreement, is the agreement between you and us that explains what data we collect, how we store and transfer it, and how we use it.
#
# Dataset Full Test:  Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE:   At Fiverr we care about your privacy.

# %%
#!pip install accelerate

# Initialize the tokenizer and the model pipeline
model_name = "meta-llama/Llama-2-7b-chat-hf"
tokenizer = AutoTokenizer.from_pretrained(model_name)
gen_pipeline = transformers.pipeline(
    "text-generation",
    model=model_name,
    tokenizer=tokenizer,
    torch_dtype=torch.float32,
    device_map="auto",
    framework="pt"
)
# Out:
# tokenizer_config.json:   0%|          | 0.00/1.62k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/188 [00:00<?, ?B/s]

# %%
# Function to generate text using the pipeline
def generate_text4(batch):
    # Process batch of prompts through the pipeline
    outputs_4 = gen_pipeline(batch['Prompt'], do_sample=True,
                           temperature=0.6, top_p=0.7, top_k=10, num_beams=3, early_stopping=False,
                           num_return_sequences=1, eos_token_id=tokenizer.eos_token_id,
                           max_length=200, truncation=True)
    # Extract the generated text and clean it up by removing the prompt text
    return {"Generated_Text": [output[0]['generated_text'].split('\n')[-1].strip() for output in outputs_4]}

# Apply the function batch-wise to the dataset
result_4 = dataset_4.map(generate_text4, batched=True, batch_size=20)
# Out:
# Map:   0%|          | 0/200 [00:00<?, ? examples/s]

# %%
ver = 4
result_4.shape
for i in range(result_4.num_rows):
  print("Sentence:",  result_4[i]['Segment'])
  print("Prompt:", result_4[i]['Prompt'])
  print("New Sentence:", result_4[i]['Generated_Text'])
  print()

import pandas as pd

# write out to file
output_file_path = f'/content/drive/My Drive/w266-personal/Final Project/PLUE/data/privacyqa/policy_train_dataset_small_loose_{sample}_{ver}.csv'

# Save to CSV
df_4 = result_4.to_pandas()
df_4.to_csv(output_file_path, index=False)
# Out:
# Sentence: Any information that you post in these locations, or in our user forum, can be read, collected, and used by anyone and could enable others to send you unsolicited messages.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: Any information that you post in these locations, or in our user forum, can be read, collected, and used by anyone and could enable others to send you unsolicited messages.
#
# New Sentence: REPHRASED SENTENCE: Anyone can read and collect information you post in certain locations, including our user forum, and use it to send you unsolicited messages.
#
# Sentence: Provide personalized experiences
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: Provide personalized experiences
#
# New Sentence: REPHRASED SENTENCE: Offer tailored experiences based on user preferences and behavior.
#
# Sentence: When you provide your information to Epic as part of the recruitment process, your information may be shared with Epic staff and certain third parties.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: When you provide your information to Epic as part of the recruitment process, your information may be shared with Epic staff and certain third parties.
#
# New Sentence: REPHRASED SENTENCE: Epic may share your recruitment information with its staff and third parties.
#
# Sentence: Our name is an acronym for the Latin         phrase Anima Sana In Corpore Sano (sound mind and sound body).
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: Our name is an acronym for the Latin         phrase Anima Sana In Corpore Sano (sound mind and sound body).
#
# New Sentence: The company's name is an acronym for the Latin phrase "Anima Sana In Corpore Sano," which means "a sound mind in a sound body."
#
# Sentence: If you do not agree to the changes, you should discontinue your use of the Services prior to the time the modified Policy takes effect.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: If you do not agree to the changes, you should discontinue your use of the Services prior to the time the modified Policy takes effect.
#
# New Sentence: REPHRASED SENTENCE: If you don't agree to the changes, stop using the services before the new policy takes effect.
#
# Sentence: Service Providers and Processor.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: Service Providers and Processor.
#
# New Sentence: Rephrased and simplified: Service Providers and Processors.
#
# Sentence: Khan Academy uses certain physical, managerial, and technical safeguards designed to preserve the integrity and security of your Personal Information and other information we maintain in connection with our Service.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: Khan Academy uses certain physical, managerial, and technical safeguards designed to preserve the integrity and security of your Personal Information and other information we maintain in connection with our Service.
#
# New Sentence: Khan Academy has implemented various measures to protect your personal information and other data, including physical, managerial, and technical safeguards.
#
# Sentence: We assign a unique ID number to your credentials to track you and your associated information.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: We assign a unique ID number to your credentials to track you and your associated information.
#
# New Sentence: REPHRASED SENTENCE: We assign a special number to identify you and your information.
#
# Sentence:  Cookies help us and third parties understand which ads you have seen so that you dont receive the same ad each time you access a Service.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE:  Cookies help us and third parties understand which ads you have seen so that you dont receive the same ad each time you access a Service.
#
# New Sentence: Simplified response: Cookies help us and others remember which ads you've seen so you don't see the same one every time you use a service.
#
# Sentence:  Usage information such as information about the Services you use, the time and duration of your use of the Services and other information about your interaction with content offered through a Service, and any information stored using cookies, mobile ad identifiers, and similar technologies that we have set on your device.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE:  Usage information such as information about the Services you use, the time and duration of your use of the Services and other information about your interaction with content offered through a Service, and any information stored using cookies, mobile ad identifiers, and similar technologies that we have set on your device.
#
# New Sentence: REPHRASED SENTENCE:  We collect information about how you use our Services, including the types of Services you use, how long you use them, and other details about your interactions with content. This may include information stored in cookies, mobile ad identifiers, and similar technologies on your device.
#
# Sentence: Information provided by partners and other sources.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: Information provided by partners and other sources.
#
# New Sentence: Simplified and rephrased: Partners and other sources provide information.
#
# Sentence: When you participate in various social media         forums like Facebook, Twitter, Yammer, Pinterest, Instagram, LinkedIn, etc.,         you should be familiar with and understand the tools provided by those sites         that allow you to make choices about how you share the personal data in your         social media profile(s).
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: When you participate in various social media         forums like Facebook, Twitter, Yammer, Pinterest, Instagram, LinkedIn, etc.,         you should be familiar with and understand the tools provided by those sites         that allow you to make choices about how you share the personal data in your         social media profile(s).
#
# New Sentence: REPHRASED SENTENCE: To make informed choices about how you share personal data on social media platforms like Facebook, Twitter, Yammer, Pinterest, Instagram, and LinkedIn, it's important to be familiar with the tools provided by these sites that allow you to manage your data.
#
# Sentence: Within thirty days of receiving such a request, we will provide a list of the categories of personal information disclosed to third parties for third party direct marketing purposes during the immediately preceding year, along with the names and addresses of those third parties.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: Within thirty days of receiving such a request, we will provide a list of the categories of personal information disclosed to third parties for third party direct marketing purposes during the immediately preceding year, along with the names and addresses of those third parties.
#
# New Sentence: REPHRASED SENTENCE: We will provide a list of personal information shared with third parties for marketing purposes within 30 days of receiving a request.
#
# Sentence: Pepperplate periodically reviews and updates these measures.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: Pepperplate periodically reviews and updates these measures.
#
# New Sentence: Simplified and rephrased: Pepperplate reviews and updates these measures regularly.
#
# Sentence: We store the information we collect for as long as it is necessary for the purpose(s) for which we originally collected it.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: We store the information we collect for as long as it is necessary for the purpose(s) for which we originally collected it.
#
# New Sentence: Simplified and rephrased: We keep the data we collect for as long as we need it for the original purpose.
#
# Sentence: We use the information that you provide for such purposes as responding to your requests, customizing future browsing for you, improving our site, and communicating with you.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: We use the information that you provide for such purposes as responding to your requests, customizing future browsing for you, improving our site, and communicating with you.
#
# New Sentence: REPHRASED SENTENCE: We use your information to respond to your requests, customize your future browsing, improve our site, and communicate with you.
#
# Sentence: Epic has a legitimate interest in processing your data in order to manage our overall recruitment process and to assess whether you are a viable candidate for a career at Epic.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: Epic has a legitimate interest in processing your data in order to manage our overall recruitment process and to assess whether you are a viable candidate for a career at Epic.
#
# New Sentence: REPHRASED SENTENCE: Epic wants to process your data to manage our recruitment process and assess your suitability for a job.
#
# Sentence: Service
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: Service
#
# New Sentence: REPHRASED SENTENCE: The quality of a product or service, the effectiveness of the customer service team, and the overall customer experience all play a role in determining customer satisfaction and loyalty.
#
# Sentence: You can view the vendors we use to help us provide the Service on our Vendors page.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: You can view the vendors we use to help us provide the Service on our Vendors page.
#
# New Sentence: REPHRASED SENTENCE: You can see the vendors we work with on our Vendors page.
#
# Sentence: However, you can open a new account at any time.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: However, you can open a new account at any time.
#
# New Sentence: REPHRASED SENTENCE: You can open a new account at any time.
#
# Sentence: We use Crash Data to identify problems in our Apps and to make our Apps better and more stable.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: We use Crash Data to identify problems in our Apps and to make our Apps better and more stable.
#
# New Sentence: REPHRASED SENTENCE: We use crash data to identify issues in our apps and improve their stability and performance.
#
# Sentence: For more information about these rights, or to submit a request, please email privacy+gdpr@brilliant.org.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: For more information about these rights, or to submit a request, please email privacy+gdpr@brilliant.org.
#
# New Sentence: Simplified response: For more info about these rights or to submit a request, email privacy+gdpr@brilliant.org.
#
# Sentence: Except for authorized law enforcement investigations, we do not use this information to identify you personally without your express consent.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: Except for authorized law enforcement investigations, we do not use this information to identify you personally without your express consent.
#
# New Sentence: REPHRASED SENTENCE: We don't use your personal information for identification purposes without your explicit consent, unless it's for authorized law enforcement investigations.
#
# Sentence: Your browser may also tell us information such as:
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: Your browser may also tell us information such as:
#
# New Sentence: SUCCINCTLY REPHRASED SENTENCE: Your browser may provide additional information such as device type, screen resolution, language preference, and location.
#
# Sentence: When you access or use our Services, we may generally collect the personal information described below.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: When you access or use our Services, we may generally collect the personal information described below.
#
# New Sentence: REPHRASED SENTENCE: When you use our Services, we may collect personal information.
#
# Sentence: Also, in the event that IMDb.com, Inc., or substantially all of its assets are acquired, user information will of course be included in the transaction.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: Also, in the event that IMDb.com, Inc., or substantially all of its assets are acquired, user information will of course be included in the transaction.
#
# New Sentence: Simplified and rephrased: If IMDb.com, Inc. is acquired, user information will be included in the deal.
#
# Sentence: We do not use Malware Scanning.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: We do not use Malware Scanning.
#
# New Sentence: REPHRASED SENTENCE: We don't use Malware Scanning.
#
# Sentence: We do not use AdMob's optional GPS/location-based ad targeting.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: We do not use AdMob's optional GPS/location-based ad targeting.
#
# New Sentence: Simplified response: We don't use AdMob's GPS/location-based ad targeting.
#
# Sentence: If you prefer that we do not share your name and address with other marketers, please see the "Right to Opt Out" section below.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: If you prefer that we do not share your name and address with other marketers, please see the "Right to Opt Out" section below.
#
# New Sentence: REPHRASED SENTENCE: You can opt out of sharing your name and address with other marketers by following the instructions in the "Right to Opt Out" section.
#
# Sentence: You can disconnect us from Integrated Services.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: You can disconnect us from Integrated Services.
#
# New Sentence: REPHRASED SENTENCE: You can disconnect us from Integrated Services.
#
# Sentence: ASICS retains your personal data for as long as required to satisfy the         purpose for which they were collected and used (for example, for the time         necessary for us to send you the newsletters you subscribed to, to provide you         with customer service, answer queries or resolve technical problems, etc.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: ASICS retains your personal data for as long as required to satisfy the         purpose for which they were collected and used (for example, for the time         necessary for us to send you the newsletters you subscribed to, to provide you         with customer service, answer queries or resolve technical problems, etc.
#
# New Sentence: Retained data may be kept for longer periods of time in the following         circumstances: (i) where we are required to do so by law; (ii) to establish,         exercise or defend a legal claim; (iii) to protect the rights, property or         safety of ASICS, its users or others; or (iv) where we have         reasonable grounds to believe that the retention of the data is necessary         to prevent or
#
# Sentence: SecurityIn those instances where we secure your personal information in transit to us and upon receipt, the Postal Service uses the industry standard encryption software, Secured Socket Layer (SSL).
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: SecurityIn those instances where we secure your personal information in transit to us and upon receipt, the Postal Service uses the industry standard encryption software, Secured Socket Layer (SSL).
#
# New Sentence: REPHRASED SENTENCE: The Postal Service uses SSL encryption to secure personal information in transit and upon receipt.
#
# Sentence:  Perform analysis about your use of, or interest in, our or others products, services, or content, including mobile analytics
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE:  Perform analysis about your use of, or interest in, our or others products, services, or content, including mobile analytics
#
# New Sentence: Simplified Response:  Analyze how you use or are interested in our or others products, services, or content, including mobile analytics.
#
# Sentence: See Section 6 below.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: See Section 6 below.
#
# New Sentence: Rephrased and simplified: See section 6.
#
# Sentence: Personal information is any information about you that is personally identifiable, such as your name, address, email address or phone number, Facebook Connect sign-in information (if applicable), and any other information that is not otherwise publicly available.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: Personal information is any information about you that is personally identifiable, such as your name, address, email address or phone number, Facebook Connect sign-in information (if applicable), and any other information that is not otherwise publicly available.
#
# New Sentence: REPHRASED SENTENCE: Personal information refers to any unique details about you, such as your name, address, email, phone number, and Facebook login details (if applicable).
#
# Sentence: They allow us to recognise and count the number of visitors and to see how visitors move around our Site when they are using it.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: They allow us to recognise and count the number of visitors and to see how visitors move around our Site when they are using it.
#
# New Sentence: REPHRASED SENTENCE: They help us track how many visitors come to our Site and how they navigate through it.
#
# Sentence: We may also retain certain information about you as required by law or for legitimate business purposes after you delete your account.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: We may also retain certain information about you as required by law or for legitimate business purposes after you delete your account.
#
# New Sentence: REPHRASED SENTENCE: We may keep some of your information as required by law or for legitimate business reasons even after you delete your account.
#
# Sentence: The page that led you to Our Website; and
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: The page that led you to Our Website; and
#
# New Sentence: REPHRASED SENTENCE: The page that led you to Our Website was created in 2010 and has been updated frequently since then.
#
# Sentence: All information you provide to us is stored on our secure servers in the Republic of Ireland.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: All information you provide to us is stored on our secure servers in the Republic of Ireland.
#
# New Sentence: REPHRASED SENTENCE: Our secure servers in the Republic of Ireland store all the information you provide to us.
#
# Sentence: ),         unless a longer period is necessary for our legal obligations or to defend a         legal claim.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: ),         unless a longer period is necessary for our legal obligations or to defend a         legal claim.
#
# New Sentence: Simplified response: We keep your data for as long as we need it for legal reasons or to defend ourselves in court.
#
# Sentence: Your use of these features enables the sharing of certain information with your friends or the public, depending on the settings you establish with the third party that provides the social sharing feature.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: Your use of these features enables the sharing of certain information with your friends or the public, depending on the settings you establish with the third party that provides the social sharing feature.
#
# New Sentence: REPHRASED SENTENCE: You can share certain information with friends or the public depending on your settings with the third-party provider of the social sharing feature.
#
# Sentence: If you choose to use the Services or provide your information to us, your personal information may be transferred to, processed and maintained on servers or databases located outside of the country or jurisdiction where you are located.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: If you choose to use the Services or provide your information to us, your personal information may be transferred to, processed and maintained on servers or databases located outside of the country or jurisdiction where you are located.
#
# New Sentence: REPHRASED SENTENCE: Your personal information may be transferred and processed outside of your location.
#
# Sentence: Suggesting Evernote service features or products to you that we think will help you get the most out of our Service.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: Suggesting Evernote service features or products to you that we think will help you get the most out of our Service.
#
# New Sentence: SUCCINCT REPHRASE: We recommend Evernote features and products to help you maximize our service.
#
# Sentence: See our Help and Learning page on opting-out for more information.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: See our Help and Learning page on opting-out for more information.
#
# New Sentence: Opting-out information can be found on our Help and Learning page.
#
# Sentence: To learn more about the privacy controls that Google, Twitter and Facebook offer and honor for those respective services, please visit here for Google, here for Twitter, and here for Facebook.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: To learn more about the privacy controls that Google, Twitter and Facebook offer and honor for those respective services, please visit here for Google, here for Twitter, and here for Facebook.
#
# New Sentence: REPHRASED SENTENCE: Visit Google's, Twitter's, and Facebook's respective websites to learn about their privacy controls and how they handle user data.
#
# Sentence: Child Users can sign up for a Khan Academy account several ways.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: Child Users can sign up for a Khan Academy account several ways.
#
# New Sentence: REPHRASED SENTENCE: Children can create a Khan Academy account in various ways.
#
# Sentence: TouchNote reserves the right to change this Privacy Policy at any time and its sole discretion, so please re-visit this page frequently.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: TouchNote reserves the right to change this Privacy Policy at any time and its sole discretion, so please re-visit this page frequently.
#
# New Sentence: REPHRASED SENTENCE: TouchNote may update its Privacy Policy at any time, so please check back frequently.
#
# Sentence: For example, if we partner with a not-for-profit organization running a contest in your region we may send you an email notifying you of the partnership or contest.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: For example, if we partner with a not-for-profit organization running a contest in your region we may send you an email notifying you of the partnership or contest.
#
# New Sentence: Simplified response: We may send you an email if we partner with a not-for-profit organization running a contest in your region.
#
# Sentence: We may use the information we collect from you when you register, make a purchase, sign up for our newsletter, respond to a survey or marketing communication, surf the website, or use certain other site features in the following ways:
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: We may use the information we collect from you when you register, make a purchase, sign up for our newsletter, respond to a survey or marketing communication, surf the website, or use certain other site features in the following ways:
#
# New Sentence: REPHRASED SENTENCE: We use the information you provide when you register, make a purchase, sign up for our newsletter, respond to a survey or marketing communication, or use certain site features to improve our website and services.
#
# Sentence: Your continued use of our Applications constitutes your acceptance of this Privacy Policy and any updates.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: Your continued use of our Applications constitutes your acceptance of this Privacy Policy and any updates.
#
# New Sentence: REPHRASED SENTENCE: By using our Applications, you agree to our Privacy Policy and any updates.
#
# Sentence: We thus may know what path(s) you took on usps.com, but we dont know who you are.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: We thus may know what path(s) you took on usps.com, but we dont know who you are.
#
# New Sentence: Rephrased and simplified: We can see the paths you took on usps.com, but we don't know your identity.
#
# Sentence: For more information about the Privacy Shield principles and to view our certification, please visit the U.S. Department of Commerces Privacy Shield website.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: For more information about the Privacy Shield principles and to view our certification, please visit the U.S. Department of Commerces Privacy Shield website.
#
# New Sentence: Simplified response: Visit the U.S. Department of Commerces Privacy Shield website for more information about the Privacy Shield principles and to view our certification.
#
# Sentence: The personal data referred         to above in the section Personal Data We Collect may also be used by         ASICS:
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: The personal data referred         to above in the section Personal Data We Collect may also be used by         ASICS:
#
# New Sentence: ASICS may use your personal data to send you marketing messages by email, SMS or other electronic means.
#
# Sentence: Which Evernote company is my data controller?
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: Which Evernote company is my data controller?
#
# New Sentence: Simplified Response: Evernote's data controller is the company Evernote Corporation.
#
# Sentence: For example, if you create or log into an Evernote account using your Google Apps credentials via single sign-on, we will have access to certain information such as your name and email address as authorized in your Google Apps profile settings.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: For example, if you create or log into an Evernote account using your Google Apps credentials via single sign-on, we will have access to certain information such as your name and email address as authorized in your Google Apps profile settings.
#
# New Sentence: Simplified response: Evernote will have access to your name and email address if you use single sign-on with your Google Apps credentials.
#
# Sentence: A user is an individual providing personal information to us via our Services, such as by creating an account with our Apps, signing up for our newsletter(s), or otherwise accessing or using our Services.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: A user is an individual providing personal information to us via our Services, such as by creating an account with our Apps, signing up for our newsletter(s), or otherwise accessing or using our Services.
#
# New Sentence: REPHRASED SENTENCE: A user is someone who provides personal information to us through our apps, newsletters, or other services.
#
# Sentence: To learn more about how our Services use your information, please click here.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: To learn more about how our Services use your information, please click here.
#
# New Sentence: Our Services use your information to provide you with a better experience and to improve our Services. By using our Services, you agree to the collection and use of your information as described in this Privacy Policy.
#
# Sentence: Do Not Track.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: Do Not Track.
#
# New Sentence: Rephrased and simplified: Do not track my online activities.
#
# Sentence: We process your personal information when you contact us to help you with any questions, concerns, disputes or issues, or to provide us with your feedback.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: We process your personal information when you contact us to help you with any questions, concerns, disputes or issues, or to provide us with your feedback.
#
# New Sentence: REPHRASED SENTENCE: When you contact us, we process your personal information to help you with your questions, concerns, disputes, or issues, or to receive your feedback.
#
# Sentence: To delete your entire account and remove all of your information displayed publicly on the Service, log into your account and select delete your account through Settings.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: To delete your entire account and remove all of your information displayed publicly on the Service, log into your account and select delete your account through Settings.
#
# New Sentence: REPHRASED SENTENCE: To completely delete your account and remove all publicly displayed information, log in and select 'Delete Account' through Settings.
#
# Sentence: The Services are intended for use only by persons who are at least 13 years of age.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: The Services are intended for use only by persons who are at least 13 years of age.
#
# New Sentence: The Services are for people aged 13 and above.
#
# Sentence: If you request a copy of your personal information that we hold, we will provide you with a copy without undue delay and free of charge, except where we are permitted by law to charge a fee.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: If you request a copy of your personal information that we hold, we will provide you with a copy without undue delay and free of charge, except where we are permitted by law to charge a fee.
#
# New Sentence: REPHRASED SENTENCE: We will provide you with a free copy of your personal information that we hold upon request, without undue delay.
#
# Sentence: Uservoice is a support and contact request management service provided by Uservoice Inc.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: Uservoice is a support and contact request management service provided by Uservoice Inc.
#
# New Sentence: REPHRASED SENTENCE: Uservoice is a service that manages support and contact requests.
#
# Sentence: web beacons, pixel tags, SDKs, etc.)
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: web beacons, pixel tags, SDKs, etc.)
#
# New Sentence: By using simpler language and avoiding technical jargon, you can help the average user understand the concept more easily.
#
# Sentence: We will keep track of your consent through a special technical cookie.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: We will keep track of your consent through a special technical cookie.
#
# New Sentence: REPHRASED SENTENCE: We'll use a technical cookie to keep track of your consent.
#
# Sentence: Your use of our Applications is subject to the of the applicable Applications' End User License Agreement.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: Your use of our Applications is subject to the of the applicable Applications' End User License Agreement.
#
# New Sentence: REPHRASED SENTENCE: You must agree to the terms of the End User License Agreement for each Application you use.
#
# Sentence: If we process your personal information based on a contract with you or based on your consent, or the processing is carried out by automated means, you may request to receive your personal information in a structured, commonly used and machine-readable format, and to have us transfer your personal information directly to another controller, where technically feasible, unless exercise of this right adversely affects the rights and freedoms of others.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: If we process your personal information based on a contract with you or based on your consent, or the processing is carried out by automated means, you may request to receive your personal information in a structured, commonly used and machine-readable format, and to have us transfer your personal information directly to another controller, where technically feasible, unless exercise of this right adversely affects the rights and freedoms of others.
#
# New Sentence: REPHRASED SENTENCE: You have the right to request that we provide your personal information in a standardized format and transfer it directly to another organization, if the processing is done through automated means.
#
# Sentence: This includes, for example, processing your subscription, sending you electronic newsletters, or enabling you to participate in the features provided by the Services.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: This includes, for example, processing your subscription, sending you electronic newsletters, or enabling you to participate in the features provided by the Services.
#
# New Sentence: Simplified response: We use your information to process your subscription, send newsletters, and enable you to use the Services.
#
# Sentence: Schools should contact us at schoolpartnerships@khanacademy.org to request deletion of Student Records associated with the Schools use of Khan Academy.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: Schools should contact us at schoolpartnerships@khanacademy.org to request deletion of Student Records associated with the Schools use of Khan Academy.
#
# New Sentence: Deletion of Student Records can be requested by contacting us at schoolpartnerships@khanacademy.org.
#
# Sentence: Afterwards, we retain some information in a depersonalized or aggregated form but not in a way that would identify you personally.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: Afterwards, we retain some information in a depersonalized or aggregated form but not in a way that would identify you personally.
#
# New Sentence: REPHRASED SENTENCE: We keep some information afterward in a way that doesn't identify you personally.
#
# Sentence: In addition to disabling cookies and other tracking technologies as described above, you may opt-out of receiving targeted advertising from participating ad networks, audience segment providers, ad serving vendors, and other service providers by visiting websites operated by the Network Advertising Initiative and Digital Advertising Alliance .
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: In addition to disabling cookies and other tracking technologies as described above, you may opt-out of receiving targeted advertising from participating ad networks, audience segment providers, ad serving vendors, and other service providers by visiting websites operated by the Network Advertising Initiative and Digital Advertising Alliance .
#
# New Sentence: Simplified response: You can opt-out of targeted ads from various providers by visiting websites operated by the Network Advertising Initiative and Digital Advertising Alliance.
#
# Sentence: You may choose to sync certain Intuit Services with information from other financial accounts.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: You may choose to sync certain Intuit Services with information from other financial accounts.
#
# New Sentence: Simplified Response: You can link other financial accounts to Intuit Services for syncing purposes.
#
# Sentence: Our age restrictions for the Service are set forth in the Terms of Use Agreement.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: Our age restrictions for the Service are set forth in the Terms of Use Agreement.
#
# New Sentence: REPHRASED SENTENCE: The age restrictions for using our Service are outlined in the Terms of Use Agreement.
#
# Sentence: Your use of our Application with that healthcare institution may be subject to that healthcare institution's policies and terms.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: Your use of our Application with that healthcare institution may be subject to that healthcare institution's policies and terms.
#
# New Sentence: REPHRASED SENTENCE: Your use of our Application with that healthcare institution may be subject to their policies and terms.
#
# Sentence: "Personal Information" includes, for example, names, postal addresses, email addresses, wireless addresses, age, credit card and other payment information, demographic information, purchase history, subscription information and/or other information that may identify you as an individual or allow online or offline contact with you as an individual.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: "Personal Information" includes, for example, names, postal addresses, email addresses, wireless addresses, age, credit card and other payment information, demographic information, purchase history, subscription information and/or other information that may identify you as an individual or allow online or offline contact with you as an individual.
#
# New Sentence: REPHRASED SENTENCE: Personal information includes names, addresses, email addresses, ages, payment information, and other details that can identify you as an individual or allow contact.
#
# Sentence: The Privacy Shield Principles require that we remain potentially liable if any third party processing subject Personal Data on our behalf fails to comply with these Privacy Shield Principles (except to the extent we are not responsible for the event giving rise to any alleged damage).
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: The Privacy Shield Principles require that we remain potentially liable if any third party processing subject Personal Data on our behalf fails to comply with these Privacy Shield Principles (except to the extent we are not responsible for the event giving rise to any alleged damage).
#
# New Sentence: REPHRASED SENTENCE: We may be held responsible if any third party processing personal data on our behalf violates the Privacy Shield Principles, unless we are not at fault.
#
# Sentence: Epic does not sell or license any information that it may collect from you from using our Applications.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: Epic does not sell or license any information that it may collect from you from using our Applications.
#
# New Sentence: Simplified and rephrased: Epic doesn't sell or share personal information collected through its apps.
#
# Sentence: Please consult your browsers Help function to learn more.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: Please consult your browsers Help function to learn more.
#
# New Sentence: Rephrased and simplified: Check your browser's Help section for more information.
#
# Sentence: Such substantial changes will take effect seven (7) days after such notice was provided on any of the above mentioned methods.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: Such substantial changes will take effect seven (7) days after such notice was provided on any of the above mentioned methods.
#
# New Sentence: REPHRASED SENTENCE: Changes will take effect 7 days after notice is provided through any of the methods listed.
#
# Sentence: 3) THIRD PARTIES COOKIES
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: 3) THIRD PARTIES COOKIES
#
# New Sentence: Third parties may use cookies and other tracking technologies to serve targeted ads based on your Service usage.
#
# Sentence: We will not condition a childs participation in an event on the provision of more information than is absolutely necessary for that promotion.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: We will not condition a childs participation in an event on the provision of more information than is absolutely necessary for that promotion.
#
# New Sentence: REPHRASED SENTENCE: We won't require more information from children than necessary for an event.
#
# Sentence: Once we have received your information, we will use strict procedures and security features to try to prevent unauthorised access.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: Once we have received your information, we will use strict procedures and security features to try to prevent unauthorised access.
#
# ...
#
# New Sentence: Simplified Response: You may have a legal right to receive notices in writing, depending on where you live.
#
# Sentence: You can also stop all information collection by our App by un-installing our App.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: You can also stop all information collection by our App by un-installing our App.
#
# New Sentence: REPHRASED SENTENCE: You can stop our App from collecting information by uninstalling it.
#
# Sentence: We have security measures in place to attempt to protect against the loss, misuse and alteration of personal information under our control.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: We have security measures in place to attempt to protect against the loss, misuse and alteration of personal information under our control.
#
# New Sentence: REPHRASED SENTENCE: We have security measures to protect personal information from loss, misuse, and alteration.
#
# Sentence: If you use one of our referral programs to refer any of our family of brands to your friends and family, we will use their email addresses to send your invitation.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: If you use one of our referral programs to refer any of our family of brands to your friends and family, we will use their email addresses to send your invitation.
#
# New Sentence: REPHRASED SENTENCE: We will use your friends' and family's email addresses to send you an invitation if you refer them to our family of brands through one of our referral programs.
#
# Sentence: Right to data portability.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: Right to data portability.
#
# New Sentence: The right to data portability is a fundamental right that allows individuals to transfer their personal data from one service provider to another, in a structured, commonly used, and machine-readable format. This right enables users to have greater control over their personal data and to switch service providers more easily, promoting competition and innovation in the digital marketplace.
#
# Sentence: We may retain certain information for legitimate business purposes or as required by law.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: We may retain certain information for legitimate business purposes or as required by law.
#
# New Sentence: Simplified and rephrased: We may keep some information for our business needs or as required by law.
#
# Sentence: To enable your participation in Khan Academy partnership arrangements.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: To enable your participation in Khan Academy partnership arrangements.
#
# New Sentence: Simplified Response: To help you participate in Khan Academy's partnership programs.
#
# Sentence: If you do not want to receive such offers, please use our User Administration pages to adjust your preferences.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: If you do not want to receive such offers, please use our User Administration pages to adjust your preferences.
#
# New Sentence: Simplified response: To stop receiving these offers, go to our User Administration pages and adjust your preferences.
#
# Sentence:  While we will take commercially reasonable security measures to help safeguard your Personal Information from unauthorized access and disclosure, no system can be completely secure.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE:  While we will take commercially reasonable security measures to help safeguard your Personal Information from unauthorized access and disclosure, no system can be completely secure.
#
# New Sentence: REPHRASED SENTENCE:  We will take reasonable measures to protect your personal information from unauthorized access and disclosure, but no system is completely secure.
#
# Sentence: Personal Data collected for purposes related to the performance of a contract between the Owner and the User shall be retained until such contract has been fully performed.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: Personal Data collected for purposes related to the performance of a contract between the Owner and the User shall be retained until such contract has been fully performed.
#
# New Sentence: REPHRASED SENTENCE: Personal data collected for contract purposes will be kept until the contract is fully completed.
#
# Sentence: You should consult the respective privacy policies of those third-party websites.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: You should consult the respective privacy policies of those third-party websites.
#
# New Sentence: REPHRASED SENTENCE: Consult the privacy policies of third-party websites.
#
# Sentence: Please note, however, that if you exercise this right, you may have to then provide express consent on a case-by-case basis for the use or disclosure of certain of your Personal Data, if such use or disclosure is necessary to enable you to utilize some or all of our Sites.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: Please note, however, that if you exercise this right, you may have to then provide express consent on a case-by-case basis for the use or disclosure of certain of your Personal Data, if such use or disclosure is necessary to enable you to utilize some or all of our Sites.
#
# New Sentence: REPHRASED SENTENCE: If you decide to exercise your right to opt-out, you may need to provide explicit consent for specific uses of your personal data on a case-by-case basis.
#
# Sentence: In addition, you may choose to add information about yourself to your profile that you can then share with friends.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: In addition, you may choose to add information about yourself to your profile that you can then share with friends.
#
# New Sentence: REPHRASED SENTENCE: You can add personal information to your profile and share it with friends.
#
# Sentence: We also offer you choices about receiving personalized advertisements.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: We also offer you choices about receiving personalized advertisements.
#
# New Sentence: REPHRASED SENTENCE: You have the option to receive personalized ads.
#
# Sentence: Place of processing: US  Privacy Policy.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: Place of processing: US  Privacy Policy.
#
# New Sentence: The place of processing for our Privacy Policy is the United States.
#
# Sentence: Under certain conditions, you may also be entitled to invoke binding arbitration for complaints not resolved by other means.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: Under certain conditions, you may also be entitled to invoke binding arbitration for complaints not resolved by other means.
#
# New Sentence: REPHRASED SENTENCE: You may also be able to use binding arbitration for complaints that are not resolved through other means.
#
# Sentence:    3.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE:    3.
#
# New Sentence: Immersion is the best way to learn about a culture.
#
# Sentence: We may use the information to improve our products and services.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: We may use the information to improve our products and services.
#
# New Sentence: Simplified and rephrased: We may use your information to improve our products and services.
#
# Sentence: This does not include selling, renting, sharing, or otherwise disclosing Personal Information of our customers for commercial purposes in violation of the commitments set forth in this Privacy Statement.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: This does not include selling, renting, sharing, or otherwise disclosing Personal Information of our customers for commercial purposes in violation of the commitments set forth in this Privacy Statement.
#
# New Sentence: REPHRASED SENTENCE: We don't sell, rent, share, or disclose our customers' personal information for commercial purposes without their consent.
#
# Sentence: In these types of transactions, customer information is typically one of the business assets that are transferred.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: In these types of transactions, customer information is typically one of the business assets that are transferred.
#
# New Sentence: The customer information is one of the assets that are transferred during these types of transactions.
#
# Sentence: The cookie will expire 30 days after your last visit.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: The cookie will expire 30 days after your last visit.
#
# New Sentence: REPHRASED SENTENCE: The cookie will expire 30 days after your last visit.
#
# Sentence: To inform our product development and marketing efforts, including our targeted advertising as described on our Cookie Information page.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: To inform our product development and marketing efforts, including our targeted advertising as described on our Cookie Information page.
#
# New Sentence: REPHRASED SENTENCE: We use data to inform our product development and marketing efforts, including targeted advertising.
#
# Sentence: We use traffic log cookies to identify which pages are being used, e.g.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: We use traffic log cookies to identify which pages are being used, e.g.
#
# New Sentence: Answer: We use cookies to track which pages you visit.
#
# Sentence: We retain Personal Data about you as long as you have an open account with us or as otherwise necessary to provide you Services.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: We retain Personal Data about you as long as you have an open account with us or as otherwise necessary to provide you Services.
#
# New Sentence: REPHRASED SENTENCE: We keep your personal data as long as you have an active account with us or until it's no longer needed to provide you with services.
#
# Sentence: Though, if you want to reset your Advertising ID, you can follow these instructions:
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: Though, if you want to reset your Advertising ID, you can follow these instructions:
#
# New Sentence: 4. Wait for the process to complete.
#
# Sentence: Content means the text, images, and other data you choose to input, upload, and store in Evernote.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: Content means the text, images, and other data you choose to input, upload, and store in Evernote.
#
# New Sentence: REPHRASED SENTENCE: Content in Evernote refers to the text, images, and other data you input, upload, and store.
#
# Sentence: The right to obtain access to your personal information, along with certain related information, and to receive that information in a commonly used format and to have it transferred to another data controller; Right to rectification.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: The right to obtain access to your personal information, along with certain related information, and to receive that information in a commonly used format and to have it transferred to another data controller; Right to rectification.
#
# New Sentence: Simplified and rephrased: You have the right to access and receive your personal information, and to have it transferred to another data controller in a commonly used format. You also have the right to request that your information be corrected if it is inaccurate.
#
# Sentence: to provide you with information about other products and services we offer that are similar to those that you have already purchased or enquired about;
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: to provide you with information about other products and services we offer that are similar to those that you have already purchased or enquired about;
#
# New Sentence: REPHRASED SENTENCE: We provide information on similar products and services we offer.
#
# Sentence: For example, we may ask you to provide certain Personal Information to confirm your identity, and we may require that you create and use a password to access certain parts of our Service.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: For example, we may ask you to provide certain Personal Information to confirm your identity, and we may require that you create and use a password to access certain parts of our Service.
#
# New Sentence: REPHRASED SENTENCE: We may ask you to provide personal information to verify your identity, and you may need to create a password to access certain parts of our service.
#
# Sentence: To help us customize the content, experience, and advertisements provided to you on our websites and Apps and on other websites across the Internet.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: To help us customize the content, experience, and advertisements provided to you on our websites and Apps and on other websites across the Internet.
#
# New Sentence: REPHRASED SENTENCE: We use data to personalize your experience on our websites and apps, and on other websites you visit.

# %% [markdown]
# ## Hyperparameter Tuning
#
# To decide the best hyper-parameters for Sentence generation for *simplifying, clarifying, and rephrasing the original sentence succinctly* I try out multiple variations of hyperparameters that can be used to control the language generation process.  These include:
#
# *   temperature - Default, 0.25, 0.35, 0.4, 0.5, 0.6
# *   top_p - Default, 0.8, 0.6, 0.7,
# *   top_k - 5, 7, 10
# *   num_beams - Default, 2, 3
# *   early_stopping - True, False
#
# ## Chosen Values for Sentence rewriting (Version 2)
#
#  * temperature=0.6,
#  * top_p=0.7,
#  * top_k=10,
#  * num_beams=3,
#  * early_stopping=False,

# %%
def get_segment(dataset, prompt):
    """
    Retrieve the segment associated with a specific prompt from a Hugging Face Dataset.

    Parameters:
    - dataset (Dataset): A Hugging Face Dataset object with columns ['Prompt', 'Segment', 'Generated_Text'].
    - prompt (str): The prompt string to search for within the dataset.

    Returns:
    - str: The segment corresponding to the given prompt. Returns 'No segment found' if the prompt does not exist.
    """
    # Filter the dataset for the target prompt
    filtered_dataset = dataset.filter(lambda example: example['Prompt'] == prompt)

    # Extract the segment for the specific prompt
    if len(filtered_dataset) > 0:
        return filtered_dataset['Segment'][0]
    else:
        return "No segment found"

# %%
import json
from datasets import concatenate_datasets, load_dataset

# Based on Trail #2; Simple prompt with SENTENCE Marker
# Low temperature; Try to flex on Top_p and Beams.
# Function to generate text using the pipeline
def generate_text_full(batch):

    # Initialize the batch counter attribute if it doesn't exist
    if not hasattr(generate_text_full, 'batch_counter'):
        generate_text_full.batch_counter = 0  # Static variable equivalent
    generate_text_full.batch_counter += 1  # Increment the counter
    print(f"Processing Batch #{generate_text_full.batch_counter}, Batch Size: {len(batch['Prompt'])}")

    try:
        # Process batch of prompts through the pipeline with torch.no_grad() for memory efficiency
        with torch.no_grad():
            outputs_full = gen_pipeline(batch['Prompt'], do_sample=True,
                           temperature=0.6, top_p=0.7, top_k=10, num_beams=3, early_stopping=False,
                           num_return_sequences=1, eos_token_id=tokenizer.eos_token_id,
                           max_length=200, truncation=True)
        # Extract the generated text and clean it up by removing the prompt text
        return {"Generated_Text": [output[0]['generated_text'].split('\n')[-1].strip() for output in outputs_full]}
    except Exception as e:
        print(f"An error occurred: {e}")
        print("Reverting to sequential processing for this batch")
        generated_texts = []
        for prompt in batch['Prompt']:
          try:
            output = gen_pipeline(prompt, do_sample=True,
                           temperature=0.6, top_p=0.7, top_k=10, num_beams=3, early_stopping=False,
                           num_return_sequences=1, eos_token_id=tokenizer.eos_token_id,
                           max_length=200, truncation=True)
            # Extract the generated text and clean it up by removing the prompt text
            generated_text = output[0]['generated_text'].split('\n')[-1].strip()

            # Append the cleaned generated text to the list
            generated_texts.append(generated_text)

          except Exception as ex:
            print(f"Error processing prompt: {prompt}.")
            print(f"Using source segment.")
            print(f"Error: {ex}")
            combined_dataset = concatenate_datasets([dataset_full, dataset_full_test])
            generated_texts.append(get_segment(combined_dataset,prompt))  # Use the original segment in case of an error

        # Return the list of generated texts
        return {"Generated_Text": generated_texts}

# %%
# Apply the function batch-wise to the dataset
result_full = dataset_full.map(generate_text_full, batched=True, batch_size=100)
# Out:
# Map:   0%|          | 0/3411 [00:00<?, ? examples/s]
# Processing Batch #1, Batch Size: 100
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Processing Batch #2, Batch Size: 100
# Processing Batch #3, Batch Size: 100
# Processing Batch #4, Batch Size: 100
# Processing Batch #5, Batch Size: 100
# Processing Batch #6, Batch Size: 100
# Processing Batch #7, Batch Size: 100
# Processing Batch #8, Batch Size: 100
# An error occurred: Input length of input_ids is 200, but `max_length` is set to 200. This can lead to unexpected behavior. You should consider increasing `max_length` or, better yet, setting `max_new_tokens`.
# Reverting to sequential processing for this batch
# Error processing prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE:  Except as otherwise described in this privacy statement, Goodreads will not disclose personal information to any third party unless required to do so by law or subpoena or if we believe that such action is necessary to (a) conform to the law, comply with legal process served on us or our affiliates, or investigate, prevent, or take action regarding suspected or actual illegal activities; (b) to enforce our Terms of Use, take precautions against liability, to investigate and defend ourselves against any third-party claims or allegations, to assist government enforcement agencies, or to protect the security or integrity of our site; and (c) to exercise or protect the rights, property, or personal safety of Goodreads, our users or others.
# .
# Using source segment.
# Error: Input length of input_ids is 200, but `max_length` is set to 200. This can lead to unexpected behavior. You should consider increasing `max_length` or, better yet, setting `max_new_tokens`.
# Filter:   0%|          | 0/4642 [00:00<?, ? examples/s]
# Processing Batch #9, Batch Size: 100
# Processing Batch #10, Batch Size: 100
# Processing Batch #11, Batch Size: 100
# Processing Batch #12, Batch Size: 100
# An error occurred: Input length of input_ids is 200, but `max_length` is set to 200. This can lead to unexpected behavior. You should consider increasing `max_length` or, better yet, setting `max_new_tokens`.
# Reverting to sequential processing for this batch
# Error processing prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE:   US: https://security.intuit.com/index.php/privacy Canada (EN): http://www.intuit.ca/about-intuit-canada/info/privacy-policy.jsp Canada (FR): http://www.intuit.ca/a-propos-de-intuit/info/vie-privee.jsp France: http://quickbooks.intuit.fr/a-propos/confidentialite.jsp UK: https://www.quickbooks.co.uk/privacy-policy/ Australia: http://www.intuit.com.au/about/privacy.jsp India: http://www.quickbooks.in/privacy.jsp Singapore: http://quickbooks.intuit.sg/about/privacy.jsp Malaysia: http://www.intuit.com.my/about/privacy.jsp Hong Kong (traditional Chinese): http://www.intuit.hk/hk/about/privacy.jsp Hong Kong (English): http://www.intuit.hk/hk-en/about/privacy.jsp Brazil: http://www.quickbooks.com.br/privacidade/ All Other Countries (Global): https://quickbooks.intuit.com/global/privacy/
# .
# Using source segment.
# Error: Input length of input_ids is 200, but `max_length` is set to 200. This can lead to unexpected behavior. You should consider increasing `max_length` or, better yet, setting `max_new_tokens`.
# Filter:   0%|          | 0/4642 [00:00<?, ? examples/s]
# Processing Batch #13, Batch Size: 100
# Processing Batch #14, Batch Size: 100
# Processing Batch #15, Batch Size: 100
# Processing Batch #16, Batch Size: 100
# Processing Batch #17, Batch Size: 100
# Processing Batch #18, Batch Size: 100
# Processing Batch #19, Batch Size: 100
# Processing Batch #20, Batch Size: 100
# An error occurred: Input length of input_ids is 200, but `max_length` is set to 200. This can lead to unexpected behavior. You should consider increasing `max_length` or, better yet, setting `max_new_tokens`.
# Reverting to sequential processing for this batch
# Error processing prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: We use your personal information which we collect in the following ways:  Information you give to us:  We will use this information to:  Take steps in order to enter into any contract or carry out our obligations arising from any contract entered into between you and us including: enabling us to process your orders and to provide you with the Services and information offered through the Services and which you request; administering the Services and your account with us; verify and carry out financial transactions in relation to payments you make online; notifying you about changes to our Service; contact you with emails, newsletters, marketing or promotional materials and other information that may be of interest to you including information about our products and services or those of carefully selected third parties, provided you have indicated that you do not object to being contacted for these purposes; and allow, with your consent, carefully selected third parties to send you information directly which you may find useful regarding their products and services.
# .
# Using source segment.
# Error: Input length of input_ids is 200, but `max_length` is set to 200. This can lead to unexpected behavior. You should consider increasing `max_length` or, better yet, setting `max_new_tokens`.
# Filter:   0%|          | 0/4642 [00:00<?, ? examples/s]
# Error processing prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: Information we collect about you from your use of our Services  We will use this information in our legitimate interests, where we have considered these are not overridden by your rights:  to administer our Services and for internal operations, including troubleshooting, data analysis, testing, research, statistical and survey purposes; to keep our Services safe and secure, and fight spam, malware and identity theft; for measuring or understanding the effectiveness of advertising we serve to you and others, including following the use of our Services and related purchases, and to deliver relevant advertising to you; to allow you to participate in interactive features of our Services, when you choose to do so; to analyze (and engage third parties to analyze) information to improve and enhance the Services by expanding their features and functionality and tailoring them to your needs and preferences, and to ensure that content is presented in the most effective manner for you and for your computer; to improve the layout and/or content of the pages of the Services and customize them for users; to identify visitors using the Services and carry out research on our users' demographics and tracking of sales data; and to generate aggregate, non-identifying information about how our Services are used.
# .
# Using source segment.
# Error: Input length of input_ids is 200, but `max_length` is set to 200. This can lead to unexpected behavior. You should consider increasing `max_length` or, better yet, setting `max_new_tokens`.
# Filter:   0%|          | 0/4642 [00:00<?, ? examples/s]
# Error processing prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: Personal information about our users is used by each such service to process payment transactions and for no other purpose, and this information is subject to  Stripes privacy policy and terms of use found at https://stripe.com/us/terms; Apples iTunes privacy policy and terms of use found at http://www.apple.com/legal/privacy/ and http://www.apple.com/legal/internet-services/itunes/us/terms.html; Google Plays privacy policy and terms of use found at https://www.google.com/intl/en/policies/privacy/ and https://play.google.com/about/play-terms.html; and Shopifys privacy policy and terms of service found at https://www.shopify.com/legal/privacy and https://www.shopify.com/legal/terms.
# .
# Using source segment.
# Error: Input length of input_ids is 200, but `max_length` is set to 200. This can lead to unexpected behavior. You should consider increasing `max_length` or, better yet, setting `max_new_tokens`.
# Filter:   0%|          | 0/4642 [00:00<?, ? examples/s]
# Processing Batch #21, Batch Size: 100
# Processing Batch #22, Batch Size: 100
# Processing Batch #23, Batch Size: 100
# An error occurred: Input length of input_ids is 200, but `max_length` is set to 200. This can lead to unexpected behavior. You should consider increasing `max_length` or, better yet, setting `max_new_tokens`.
# Reverting to sequential processing for this batch
# Error processing prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: TripAdvisor uses the information we collect about you for the following general purposes: for registration and to manage your account, including to allow your access to and use of our site; to communicate with you in general, including to provide information about TripAdvisor and invitations from the TripAdvisor community; to enable us to publish your reviews, forum posts, and other content to the TripAdvisor community; to facilitate your booking of travel reservations; to respond to your questions and comments; to measure interest in and improve our products, services, and Website; to notify you about special offers and products or services available from us or our partners that may be of interest to you; to otherwise customize your experience with TripAdvisor, including customizing the ads shown to you; to solicit information from you, including through surveys; to resolve disputes or troubleshoot problems; to prevent potentially prohibited or illegal activities; to enforce our Terms of Use; and as otherwise described to you at the point of collection.
# .
# Using source segment.
# Error: Input length of input_ids is 200, but `max_length` is set to 200. This can lead to unexpected behavior. You should consider increasing `max_length` or, better yet, setting `max_new_tokens`.
# Filter:   0%|          | 0/4642 [00:00<?, ? examples/s]
# Processing Batch #24, Batch Size: 100
# An error occurred: Input length of input_ids is 200, but `max_length` is set to 200. This can lead to unexpected behavior. You should consider increasing `max_length` or, better yet, setting `max_new_tokens`.
# Reverting to sequential processing for this batch
# Error processing prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: Data may be processed for   the following purposes: a) management of the registration to Triposo Website or App; b) publication of and access to tips   and reviews written by the Data subjects in relation to destinations and Points of interests, services, attractions and   trips mentioned on the Website; g) statistical purposes on anonymized data; c) delivery by Triposo of promotional communications   about discounts, offers, events or services similar to those previously seen by the Data subject; d) delivery by Triposo   of promotional communications about discounts, offers, events or services different from those previously seen by the Data   subjest, only with his/her explicit consent; e) profiling activities, that is evaluating the tastes, preferences and consumption   habits of the Data subject, including by inviting him/her to participate in market surveys, only with his/her explicit   consent; f) communication of the personal data of the Data subject to Triposo third-party partners for the purpose of delivery   of commercial and promotional communications by the aforementioned companies, only with the explicit consent of the Data   subject.
# .
# Using source segment.
# Error: Input length of input_ids is 200, but `max_length` is set to 200. This can lead to unexpected behavior. You should consider increasing `max_length` or, better yet, setting `max_new_tokens`.
# Filter:   0%|          | 0/4642 [00:00<?, ? examples/s]
# Error processing prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: The Data subject has the right to: a) obtain the termination of processing for direct marketing purposes, also in relation   to services identical to those already provided by our company; b) obtain information in relation to the purposes for which   Data are processed, to the period of processing and to the subjects to whom the data are communicated (right of access);   c) obtain the rectification or integration of incorrect Data concerning the Data subject (right to rectification); d) obtain   the deletion of Data concerning the Data subject in the following cases (i) the data are no longer necessary for the purposes   for which they were collected; (ii) the Data subject has withdrawn his/her consent to the processing of Data, if these   are processed on the basis of his consent; (iii) the Data subject has opposed the processing of Data concerning him/her,   in case these are processed for our legitimate interest; or (iv) the processing of Data does not comply with the law.
# .
# Using source segment.
# Error: Input length of input_ids is 200, but `max_length` is set to 200. This can lead to unexpected behavior. You should consider increasing `max_length` or, better yet, setting `max_new_tokens`.
# Filter:   0%|          | 0/4642 [00:00<?, ? examples/s]
# Error processing prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: However,   it is to be noted that the retention of Data by Inter is also lawful if it is necessary in order to fulfil a legal obligation   or to ascertain, exercise or defend a right in Court (cancellation right); b) to obtain that the Data concerning the Data   subject are only stored without any further use in the following cases: (i) the Data subject disputes the accuracy of the   Data, for the period that is necessary for allowing Inter to verify the accuracy of such Data; (ii) the processing is unlawful   but the Data subject objects to the deletion of the Data; (iii) the Data are necessary for ascertaining, exercising or   defending a right in Court; (iv) the Data subject has opposed the processing and is awaiting the verification of the possible   prevalence of Inters legitimate interest to the processing (limitation right); f) receive in a common, structured, commonly   used and machine-readable format, all Data concerning the Data subject, if these are processed under a contract or on the   basis of the Data subjects consent (portability right).
# .
# Using source segment.
# Error: Input length of input_ids is 200, but `max_length` is set to 200. This can lead to unexpected behavior. You should consider increasing `max_length` or, better yet, setting `max_new_tokens`.
# Filter:   0%|          | 0/4642 [00:00<?, ? examples/s]
# Processing Batch #25, Batch Size: 100
# Processing Batch #26, Batch Size: 100
# Processing Batch #27, Batch Size: 100
# Processing Batch #28, Batch Size: 100
# Processing Batch #29, Batch Size: 100
# Processing Batch #30, Batch Size: 100
# Processing Batch #31, Batch Size: 100
# Processing Batch #32, Batch Size: 100
# Processing Batch #33, Batch Size: 100
# Processing Batch #34, Batch Size: 100
# Processing Batch #35, Batch Size: 11

# %% [markdown]
# ## Save Unique Values to File
#
# Print out a small sample for visual inspection. Wrtie the full set out to file.

# %%
import pandas as pd

# write out to file
output_file_path = f'/content/drive/My Drive/w266-personal/Final Project/PLUE/data/privacyqa/policy_train_dataset_full_loose.csv'

# Save to CSV
df_full = result_full.to_pandas()
df_full.to_csv(output_file_path, index=False)

# %% [markdown]
# # Test Set "rewriting" Simplification
#
# Let's rewrite the test QA sentences using the same LLM text generation process

# %%
# Apply the function batch-wise to the dataset
result_full_test = dataset_full_test.map(generate_text_full, batched=True, batch_size=100)
# Out:
# Map:   0%|          | 0/1231 [00:00<?, ? examples/s]
# Processing Batch #36, Batch Size: 100
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Processing Batch #37, Batch Size: 100
# Processing Batch #38, Batch Size: 100
# Processing Batch #39, Batch Size: 100
# An error occurred: Input length of input_ids is 200, but `max_length` is set to 200. This can lead to unexpected behavior. You should consider increasing `max_length` or, better yet, setting `max_new_tokens`.
# Reverting to sequential processing for this batch
# Error processing prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: with relevantBusiness Partners:with whom we jointly offer products and services;with whom we have entered into an agreement that provides for the disclosure, sale, lease, or license of your Information;to facilitate a direct relationship with you, including in connection with any program we administer on behalf of theBusiness Partner;to enable electronic communications with you as part of purchase, a sponsored reward, offer, contest, program, or other activity in which you have elected to participate;to the extent you have purchased or redeemed a Groupon voucher, goods or services offered by aBusiness Partneror participated in an offer, rewards, contest or other activity orOther Programssponsored or offered through Groupon on behalf of thatBusiness Partner;
# .
# Using source segment.
# Error: Input length of input_ids is 200, but `max_length` is set to 200. This can lead to unexpected behavior. You should consider increasing `max_length` or, better yet, setting `max_new_tokens`.
# Filter:   0%|          | 0/4642 [00:00<?, ? examples/s]
# Processing Batch #40, Batch Size: 100
# Processing Batch #41, Batch Size: 100
# Processing Batch #42, Batch Size: 100
# An error occurred: Input length of input_ids is 200, but `max_length` is set to 200. This can lead to unexpected behavior. You should consider increasing `max_length` or, better yet, setting `max_new_tokens`.
# Reverting to sequential processing for this batch
# Error processing prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: Your information may be disclosed: (i) when we have a good faith belief that we are required to disclose the information in response to legal process (for example, a court order, search warrant or subpoena); (ii) to satisfy any applicable laws or regulations; (iii) where we believe that the Games are being used in the commission of a crime, including to report such criminal activity or to exchange information with other companies and organizations for the purposes of fraud protection and credit risk reduction; (iv) when we have a good faith belief that there is an emergency that poses a threat to the health and/or safety of you, another person or the public generally; and (v) in order to protect the rights or property of PeopleFun, including to enforce our Terms of Service.
# .
# Using source segment.
# Error: Input length of input_ids is 200, but `max_length` is set to 200. This can lead to unexpected behavior. You should consider increasing `max_length` or, better yet, setting `max_new_tokens`.
# Filter:   0%|          | 0/4642 [00:00<?, ? examples/s]
# Processing Batch #43, Batch Size: 100
# Processing Batch #44, Batch Size: 100
# An error occurred: Input length of input_ids is 200, but `max_length` is set to 200. This can lead to unexpected behavior. You should consider increasing `max_length` or, better yet, setting `max_new_tokens`.
# Reverting to sequential processing for this batch
# Error processing prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: open your account, enable purchases and process payments, communicate with you, and implement your requests (eg, referrals); enable and enhance your use of our website and mobile application(s), including authenticatint your visits, providing personalized content and information, and tracking your usage of our Services; contact you about your account, and any relevant information about our Services (eg policy changes, security updates or issues, etc); enforce our Terms of Service and other agreements; monitor, detect, investigate and prevent prohibited or illegal behaviors on our Services, to combat spam and other security risks; and perform research & development activities, which may include, for example, conducting data analysis and research in order to develop new or improve existing products and services, and performing quality control activities.
# .
# Using source segment.
# Error: Input length of input_ids is 200, but `max_length` is set to 200. This can lead to unexpected behavior. You should consider increasing `max_length` or, better yet, setting `max_new_tokens`.
# Filter:   0%|          | 0/4642 [00:00<?, ? examples/s]
# Processing Batch #45, Batch Size: 100
# An error occurred: Input length of input_ids is 200, but `max_length` is set to 200. This can lead to unexpected behavior. You should consider increasing `max_length` or, better yet, setting `max_new_tokens`.
# Reverting to sequential processing for this batch
# Error processing prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: 23andMe will preserve and disclose any and all information to law enforcement agencies or others if required to do so by law or in the good faith belief that such preservation or disclosure is reasonably necessary to: (a) comply with legal or regulatory process (such as a judicial proceeding, court order, or government inquiry) or obligations that 23andMe may owe pursuant to ethical and other professional rules, laws, and regulations; (b) enforce the 23andMe Terms of Service and other policies; (c) respond to claims that any content violates the rights of third parties; or (d) protect the rights, property, or personal safety of 23andMe, its employees, its users, its clients, and the public.
# .
# Using source segment.
# Error: Input length of input_ids is 200, but `max_length` is set to 200. This can lead to unexpected behavior. You should consider increasing `max_length` or, better yet, setting `max_new_tokens`.
# Filter:   0%|          | 0/4642 [00:00<?, ? examples/s]
# Processing Batch #46, Batch Size: 100
# Processing Batch #47, Batch Size: 100
# An error occurred: Input length of input_ids is 200, but `max_length` is set to 200. This can lead to unexpected behavior. You should consider increasing `max_length` or, better yet, setting `max_new_tokens`.
# Reverting to sequential processing for this batch
# Error processing prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: (a)Make our service available: We use your Registration and Account information to (i) register you for the App and create your User Account for Viber; (ii) create your profile and make it visible; (iii) process your payments; (iv) create your Viber ID; (v) provide customer service, give you information about your account, and respond to your requests; (vi) personalize your experience by providing content (such as games) on the Service, including targeted advertising of Viber services and other 3rd party services that we believe may be of most interest to you; personalization may include automated decisions about what you will view and when, but be assure that it will not have legal effects on you (vii) indicate which of your contacts is already a Viber member and notify you when your contacts become active on the Service (viii) display the name of the contact as it appears in your address book when a call is received on the Service, and (ix) sync your contacts with Viber running on Windows, MacOS, Linux, Android tablets, iPads and Windows Tablets.
# .
# Using source segment.
# Error: Input length of input_ids is 200, but `max_length` is set to 200. This can lead to unexpected behavior. You should consider increasing `max_length` or, better yet, setting `max_new_tokens`.
# Filter:   0%|          | 0/4642 [00:00<?, ? examples/s]
# Processing Batch #48, Batch Size: 31

# %% [markdown]
# ## Save Unique Values to File
#
# Print out a small sample for visual inspection. Wrtie the full set out to file.

# %%
sample = 50
ver = "full_test"
result_full_test.shape
for i in range(sample):
  print("Sentence:",  result_full_test[i]['Segment'])
  print("Prompt:", result_full_test[i]['Prompt'])
  print("New Sentence:", result_full_test[i]['Generated_Text'])
  print()

import pandas as pd

# write out to file
output_file_path = f'/content/drive/My Drive/w266-personal/Final Project/PLUE/data/privacyqa/policy_test_dataset_full_loose.csv'

# Save to CSV
df_full_test = result_full_test.to_pandas()
df_full_test.to_csv(output_file_path, index=False)
# Out:
# Sentence:   At Fiverr we care about your privacy.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE:   At Fiverr we care about your privacy.
#
# New Sentence: REPHRASED SENTENCE:  Fiverr cares about your privacy.
#
# Sentence: We do not sell or rent your personal information to third parties for their direct marketing purposes without your explicit consent.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: We do not sell or rent your personal information to third parties for their direct marketing purposes without your explicit consent.
#
# New Sentence: REPHRASED SENTENCE: We don't share your personal information with third parties for their marketing purposes without your consent.
#
# Sentence: We do not disclose it to others except as disclosed in this Policy or required to provide you with the services of the Site and mobile applications, meaning - to allow you to buy, sell, share the information you want to share on the Site; to contribute on the forum; pay for products; post reviews and so on; or where we have a legal obligation to do so.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: We do not disclose it to others except as disclosed in this Policy or required to provide you with the services of the Site and mobile applications, meaning - to allow you to buy, sell, share the information you want to share on the Site; to contribute on the forum; pay for products; post reviews and so on; or where we have a legal obligation to do so.
#
# New Sentence: REPHRASED SENTENCE: We do not share your information with others unless it is disclosed in this privacy policy or required to provide you with services on the Site and mobile applications, such as buying, selling, sharing information on the Site, contributing to the forum, paying for products, posting reviews, or where we have a legal oblig
#
# Sentence:   We collect information that you provide us or voluntarily share with other users, and also some general technical information that is automatically gathered by our systems, such as IP address, browser information and cookies to enable you to have a better user experience and a more personalized browsing experience.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE:   We collect information that you provide us or voluntarily share with other users, and also some general technical information that is automatically gathered by our systems, such as IP address, browser information and cookies to enable you to have a better user experience and a more personalized browsing experience.
#
# New Sentence: REPHRASED SENTENCE:  We collect information you provide or share with others, plus technical details like IP address and browser info to improve your browsing experience.
#
# Sentence:   We will not share information that you provide us in the process of the registration - including your contact information - except as described in this Policy.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE:   We will not share information that you provide us in the process of the registration - including your contact information - except as described in this Policy.
#
# New Sentence: REPHRASED SENTENCE:  We won't share your personal information collected during registration with anyone except as described in this Privacy Policy.
#
# Sentence:   Information that you choose to publish on the Site (photos, videos, text, music, reviews, deliveries) - is no longer private, just like any information you publish online.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE:   Information that you choose to publish on the Site (photos, videos, text, music, reviews, deliveries) - is no longer private, just like any information you publish online.
#
# New Sentence: REPHRASED SENTENCE:  The information you share on the Site, such as photos, videos, text, music, reviews, and deliveries, is no longer private like information shared online.
#
# Sentence:   Technical information that is gathered by our systems, or third party systems, automatically may be used for Site operation, optimization, analytics, content promotion and enhancement of user experience.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE:   Technical information that is gathered by our systems, or third party systems, automatically may be used for Site operation, optimization, analytics, content promotion and enhancement of user experience.
#
# New Sentence: REPHRASED SENTENCE:  Our systems and third-party systems automatically collect technical information to operate, optimize, analyze, promote content, and enhance user experience.
#
# Sentence: We may use your information to contact you - to provide notices related to your activities, or offer you promotions and general updates, but we will not let any other person, including sellers and buyers, contact you, other than through your user profile on the Site.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: We may use your information to contact you - to provide notices related to your activities, or offer you promotions and general updates, but we will not let any other person, including sellers and buyers, contact you, other than through your user profile on the Site.
#
# New Sentence: REPHRASED SENTENCE: We may use your information to contact you directly, but we won't share your contact details with other users, including sellers and buyers, unless you choose to share them through your user profile on the Site.
#
# Sentence:   Your personal information may be stored in systems based around the world, and may be processed by third party service providers acting on our behalf.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE:   Your personal information may be stored in systems based around the world, and may be processed by third party service providers acting on our behalf.
#
# New Sentence: REPHRASED SENTENCE:  Your personal data may be stored in various systems globally and processed by third-party service providers working on our behalf.
#
# Sentence: These providers may be based in countries that do not provide an equivalent level of protection for privacy as that enjoyed in the country in which you live.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: These providers may be based in countries that do not provide an equivalent level of protection for privacy as that enjoyed in the country in which you live.
#
# New Sentence: REPHRASED SENTENCE: These providers may be based in countries with lower privacy standards than your home country.
#
# Sentence: In that case, we will provide for adequate safeguards to protect your personal information.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: In that case, we will provide for adequate safeguards to protect your personal information.
#
# New Sentence: REPHRASED SENTENCE: We will protect your personal information.
#
# Sentence:   You can exercise your rights over your personal information, by opening a Customer Relations ticket.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE:   You can exercise your rights over your personal information, by opening a Customer Relations ticket.
#
# New Sentence: REPHRASED SENTENCE:  You can access and control your personal information through a Customer Relations ticket.
#
# Sentence: If you do not have an active Fiverr account, please contact us at privacy@fiverr.com.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: If you do not have an active Fiverr account, please contact us at privacy@fiverr.com.
#
# New Sentence: REPHRASED SENTENCE: Contact privacy@fiverr.com if you don't have an active Fiverr account.
#
# Sentence: More details about the rights applicable to you are in the long version of the Policy.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: More details about the rights applicable to you are in the long version of the Policy.
#
# New Sentence: REPHRASED SENTENCE: You can find more information about your rights in the full version of the Policy.
#
# Sentence:   The above are just the highlights.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE:   The above are just the highlights.
#
# New Sentence: Simplified and rephrased: The highlights are just a few of the key points.
#
# Sentence: We encourage you to read more about the information we collect, how we use it, understand the meaning of cookie (no, you cant eat it) and more in the long version of our Policy below.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: We encourage you to read more about the information we collect, how we use it, understand the meaning of cookie (no, you cant eat it) and more in the long version of our Policy below.
#
# New Sentence: REPHRASED SENTENCE: Read more about our data collection practices and how we use them in the Policy below.
#
# Sentence:   Fiverr (including Fiverr Inc., Fiver International Ltd. and its affiliates) respects your privacy and is committed to protect the personal information of its users - buyers, sellers, and visitors browsing the Site (Users).
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE:   Fiverr (including Fiverr Inc., Fiver International Ltd. and its affiliates) respects your privacy and is committed to protect the personal information of its users - buyers, sellers, and visitors browsing the Site (Users).
#
# New Sentence: REPHRASED SENTENCE: Fiverr respects users' privacy and is committed to protecting their personal information.
#
# Sentence: We believe that you have a right to know our practices regarding the information we may collect when you visit and/or use the Site.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: We believe that you have a right to know our practices regarding the information we may collect when you visit and/or use the Site.
#
# New Sentence: REPHRASED SENTENCE: You have the right to know our practices regarding information collection when visiting and using our website.
#
# Sentence: This Policy explains our privacy practices for the Site and services provided by Fiverr.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: This Policy explains our privacy practices for the Site and services provided by Fiverr.
#
# New Sentence: REPHRASED SENTENCE: Fiverr's privacy policy explains how we collect, use, and protect personal information from users of our website and services.
#
# Sentence: By accessing and/or using the Site and its related sites, applications, services, goods and/or registering for a Fiverr account, you agree to the terms and conditions of this Policy, including to our collection, use, disclosure, processing and retention of your personal information.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: By accessing and/or using the Site and its related sites, applications, services, goods and/or registering for a Fiverr account, you agree to the terms and conditions of this Policy, including to our collection, use, disclosure, processing and retention of your personal information.
#
# New Sentence: REPHRASED SENTENCE: By using Fiverr, you agree to our privacy policy, which includes collecting, using, disclosing, processing, and retaining your personal information.
#
# Sentence: You can also learn how to limit sharing of information in this Policy.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: You can also learn how to limit sharing of information in this Policy.
#
# New Sentence: REPHRASED SENTENCE: You can learn how to limit what information is shared in this Policy.
#
# Sentence:   When you register to the Site we ask you to provide certain personal information, including a valid email address, location, facebook or google account log in details and username.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE:   When you register to the Site we ask you to provide certain personal information, including a valid email address, location, facebook or google account log in details and username.
#
# New Sentence: REPHRASED SENTENCE:  When you sign up for the Site, we ask for your email address, location, Facebook or Google account login details, and username.
#
# Sentence: We may collect additional information such as physical address, telephone number or other contact details and additional authentication information, to provide you with the services you need (such as payment or withdrawal of funds, sending physical goods), or to ensure the marketplace integrity (for example, prevention of fraud).
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: We may collect additional information such as physical address, telephone number or other contact details and additional authentication information, to provide you with the services you need (such as payment or withdrawal of funds, sending physical goods), or to ensure the marketplace integrity (for example, prevention of fraud).
#
# New Sentence: Simplified response: We may collect more information to provide you with services or ensure marketplace integrity.
#
# Sentence:   In addition, we collect information while you access, browse, view or otherwise use the Site.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE:   In addition, we collect information while you access, browse, view or otherwise use the Site.
#
# New Sentence: REPHRASED SENTENCE:  We collect information when you use our website.
#
# Sentence: In other words, when you access the Site we are aware of your usage of the Site, and may gather, collect and record the information relating to such usage, including geo-location information, IP address, device and connection information, browser information and web-log information, and all communications recorded by Users through the Site.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: In other words, when you access the Site we are aware of your usage of the Site, and may gather, collect and record the information relating to such usage, including geo-location information, IP address, device and connection information, browser information and web-log information, and all communications recorded by Users through the Site.
#
# New Sentence: REPHRASED SENTENCE: We collect information about how you use our website, including your location, device and connection information, browser details, and any messages you send through the site.
#
# Sentence: We use that information to enhance user experience, personalize your browsing experience as well as monitor the Site for preventing fraud and inappropriate content or behaviour.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: We use that information to enhance user experience, personalize your browsing experience as well as monitor the Site for preventing fraud and inappropriate content or behaviour.
#
# New Sentence: REPHRASED SENTENCE: We use your information to improve your experience on the Site, personalize your browsing, and monitor for fraud and inappropriate content or behavior.
#
# Sentence: We may also collect supplemental information obtained from third parties such as demographic and navigation data.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: We may also collect supplemental information obtained from third parties such as demographic and navigation data.
#
# New Sentence: REPHRASED SENTENCE: We may collect information from third parties, such as demographic data and navigation data.
#
# Sentence:   Additionally, in order to improve your online experience at Fiverr, we have implemented impression reporting.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE:   Additionally, in order to improve your online experience at Fiverr, we have implemented impression reporting.
#
# New Sentence: REPHRASED SENTENCE:  Fiverr has introduced impression reporting to enhance your online experience.
#
# Sentence: While you view our ads, we may gather user Global Unique Identifier, HTTP request data like, user agent, IP, host, url, country/continent from which request made, browser info, device/operating system/operating system version.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: While you view our ads, we may gather user Global Unique Identifier, HTTP request data like, user agent, IP, host, url, country/continent from which request made, browser info, device/operating system/operating system version.
#
# New Sentence: Simplified response: We may collect user data, including their unique identifier, HTTP request information, and details about their device and operating system, while they view our ads.
#
# Sentence:   Once you register, your username and additional information regarding your activity is made public and is visible to all Users of the Site.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE:   Once you register, your username and additional information regarding your activity is made public and is visible to all Users of the Site.
#
# New Sentence: REPHRASED SENTENCE:  After registering, your username and activity details become publicly visible to all Site users.
#
# Sentence: This information includes photos you upload, your published portfolio, Gig information, ratings, and additional information you may choose to add to your profile.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: This information includes photos you upload, your published portfolio, Gig information, ratings, and additional information you may choose to add to your profile.
#
# New Sentence: REPHRASED SENTENCE: Your profile includes photos you upload, your published portfolio, ratings, and any additional information you choose to add.
#
# Sentence:   You directly provide us with most of the information we collect.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE:   You directly provide us with most of the information we collect.
#
# New Sentence: REPHRASED SENTENCE:  We collect most of the information from you directly.
#
# Sentence: You do this by filling out the registration details on the Site, and by posting and sharing additional information voluntarily.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: You do this by filling out the registration details on the Site, and by posting and sharing additional information voluntarily.
#
# New Sentence: REPHRASED SENTENCE: Fill out the registration details on the Site and share additional information voluntarily to create an account.
#
# Sentence: This can include information about sellers and their Gigs, User's location, sharing of portfolio, ratings and feedbacks by buyers and anything you choose to add to your user profile.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: This can include information about sellers and their Gigs, User's location, sharing of portfolio, ratings and feedbacks by buyers and anything you choose to add to your user profile.
#
# New Sentence: REPHRASED SENTENCE: This can include information about sellers and their services, location, portfolio, ratings, and feedback from buyers.
#
# Sentence: We also collect technical information indirectly and automatically through our systems.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: We also collect technical information indirectly and automatically through our systems.
#
# New Sentence: REPHRASED SENTENCE: We collect technical information automatically through our systems.
#
# Sentence: This information may include logging your Internet Protocol (IP) address, software configuration, operating system and use of cookies (cookies are small files sent from us to your computer and sometimes back).
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: This information may include logging your Internet Protocol (IP) address, software configuration, operating system and use of cookies (cookies are small files sent from us to your computer and sometimes back).
#
# New Sentence: The company may collect information about your computer or device, including your IP address, software configuration, operating system, and use of cookies (cookies are small files sent from us to your computer and sometimes back).
#
# Sentence: Cookies ultimately help us improve your navigation and ease of use of our Site.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: Cookies ultimately help us improve your navigation and ease of use of our Site.
#
# New Sentence: Simplified and rephrased: Cookies help us make our website easier to use and more enjoyable for you.
#
# Sentence: You can find further information about Cookies in this Policy below, under "Cookies".
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: You can find further information about Cookies in this Policy below, under "Cookies".
#
# New Sentence: REPHRASED SENTENCE: Find more information about Cookies in the Policy below.
#
# Sentence: We may also collect information from commercially available sources such as data aggregators and public databases.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: We may also collect information from commercially available sources such as data aggregators and public databases.
#
# New Sentence: Simplified Response: We collect information from commercial sources like data aggregators and public databases.
#
# Sentence:   Where relevant under applicable laws, all processing of your personal information will be justified by a "condition" for processing.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE:   Where relevant under applicable laws, all processing of your personal information will be justified by a "condition" for processing.
#
# New Sentence: REPHRASED SENTENCE:  Under applicable laws, your personal information may be processed based on a valid legal reason, such as a "condition" for processing.
#
# Sentence: In the majority of cases, processing will be justified on the basis that:
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: In the majority of cases, processing will be justified on the basis that:
#
# New Sentence: REPHRASED SENTENCE: In most cases, processing will be justified by showing that it is necessary for a legitimate purpose.
#
# Sentence:    you have provided your consent for us to use your personal information for a specific purpose;
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE:    you have provided your consent for us to use your personal information for a specific purpose;
#
# New Sentence: REPHRASED SENTENCE:  You gave us permission to use your personal information for a particular purpose.
#
# Sentence:    our use of your personal information is necessary to perform a contract or take steps to enter into a contract with you (e.g.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE:    our use of your personal information is necessary to perform a contract or take steps to enter into a contract with you (e.g.
#
# New Sentence: REPHRASED SENTENCE:  We use your personal information to fulfill contractual obligations or prepare to enter into a contract with you.
#
# Sentence: to provide you with services which you have purchased);
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: to provide you with services which you have purchased);
#
# New Sentence: Rephrased and simplified: We're here to help you with the services you've bought.
#
# Sentence:    the processing is necessary to comply with a relevant legal obligation or regulatory obligation that we have (e.g.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE:    the processing is necessary to comply with a relevant legal obligation or regulatory obligation that we have (e.g.
#
# New Sentence: The processing is necessary to comply with a relevant legal obligation or regulatory obligation that we have.
#
# Sentence: fraud prevention); or
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: fraud prevention); or
#
# New Sentence: Please provide more context or clarify your question. I'm not sure I understand what you are asking. Are you looking for information on how to prevent fraud? If so, there are many resources available that can help you understand the different types of fraud and how to protect yourself from becoming a victim. Alternatively, if you have any specific questions or concerns about fraud prevention, feel free to ask and I will do my best to assist you.
#
# Sentence:    the processing is necessary to support our legitimate interests as a business (e.g.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE:    the processing is necessary to support our legitimate interests as a business (e.g.
#
# New Sentence: Answer:  We use your data to support our business interests, such as improving our services and personalizing your experience.
#
# Sentence: to improve our services to you or to customise your browsing experience), subject to your interests and fundamental rights and provided it is conducted at all times in a way that is proportionate.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: to improve our services to you or to customise your browsing experience), subject to your interests and fundamental rights and provided it is conducted at all times in a way that is proportionate.
#
# New Sentence: REPHRASED SENTENCE: We may use your data to improve our services and customize your browsing experience, but only if it's necessary and we do it in a way that's fair and respects your privacy.
#
# Sentence: We will use your personal information for the following purposes:
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE: We will use your personal information for the following purposes:
#
# New Sentence: REPHRASED SENTENCE: We will use your personal information for various purposes.
#
# Sentence:    to provide you with quality service and security.
# Prompt: Succinctly rephrase and simplify the 'SENTENCE' for clarity for an average user and do not add any qualifiying statements to the response.  SENTENCE:    to provide you with quality service and security.
#
# New Sentence: REPHRASED SENTENCE:  We aim to give you top-notch service and protection.

# %% [markdown]
# # Save Unique Values to File for Trail Attempts
#
# All the various Trial attemps from 1 -> 6
# Print out a small sample for visual inspection. Wrtie the full set out to file.

# %% [markdown]
# # Clean up and format output for our modeling files
# The output, upon inspection, has multiple types of labels that precede sentences like:
#
# * "REPHRASED SENTENCE:",
# * "ANALYSIS:",
# * "CLEAR AND CLEAR SENTENCE:",
# * etc.
#
# We want to extract the sentences without these labels.  We'll do this with Regular expressions (regex).

# %%
def clean_generated_text(example):
    # Define the list of specific prefixes to remove
    prefixes = [
        "REPHRASED SENTENCE", "ANONYMIZED =", "SIMPLIFIED SENTENCE",
        "Answer", "CORRECTED SENTENCE", "Rephrased and simplified sentence",
        "Simplified Rephrased Sentence", "Rephrased and simplified",
"Simplified Response",
"Simplified",
"Simplified and rephrased",
"SUCCINCT REPHRASE",
"Rephrased and simplified",
"The simplified and rephrased sentence is",
"Simplified and rephrased sentence",
"ANONYMIZATION",
"Simplified Rephrased Response",
"SUCCINCT REPHRASING",
"CORRECTED SENTENCE",
"Rephrased and simplified sentence",
"Rephrased",
"The sentence \"The company's new policy requires all employees to use their personal laptops for work-related tasks by the end of the year.\" can be rephrased and simplified as",
"Revised SENTENCE",
"Retained responses",
"Simpliifed Response",
"The simplified sentence is",
"The sentence can be rephrased as",
"The simplified rephrased sentence is",
"The sentence is rephrased and simplified as",
"New services =",
"The sentence can be rephrased and simplified as",
"RENDERED SENTENCE",
"The 'SENTENCE' can be rephrased as",
"Simplified explanation",
"The sentence is rephrased as",
"Rephrase and simplify the sentence for an average user.",
"ACCESSIBLE VERSION",
"SUCCINCTLY REPHRASED SENTENCE",
"SIMPLIFIED REPHRASE",
"Modified sentence",
"NICKNAME",
"The sentence \"if you enter into a website, it recognizes you during your next visit\" can be rephrased and simplified as",
"Simplified response",
"Simplified Rephrased Sentence",
"Rephrased and simplified sentence",
"SUCCINCT REPHRASE",
"SUMMARIZED SENTENCE",
"REPHRASED SENTEN",
"Simpliified response"
    ]

    # Prepare regex to match any of these prefixes at the start of a string followed by possible colon and spaces
    import re
    pattern = re.compile(r'^(?:' + '|'.join(re.escape(prefix) for prefix in prefixes) + r')\s*[:=]?\s*')

    # Function to clean each text in the list
    def clean_text(text):
        # Apply regex to remove the prefix and strip whitespace
        return pattern.sub('', text).strip()

    # Apply the cleaning function to each text in the list 'Generated_Text'
    cleaned_texts = [clean_text(text) for text in example['Generated_Text']]

    return {'Clean_Gen_Segment': cleaned_texts}

# %%
# 'result_full' is the Dataset object from the previous text generation step
cleaned_results_train = result_full.map(clean_generated_text, batched=True)
cleaned_results_test = result_full_test.map(clean_generated_text, batched=True)
# Out:
# Map:   0%|          | 0/3411 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1231 [00:00<?, ? examples/s]

# %%
cleaned_results_train.to_pandas().head()
# Out:
#                                              Segment  \
# 0   This privacy policy, with our Terms of Servic...
# 1  We encourage you to read this privacy policy c...
# 2  By using our application or other online servi...
# 3   When we post changes to this privacy policy, ...
# 4  We encourage you to review this privacy policy...
#
#                                               Prompt  \
# 0  Succinctly rephrase and simplify the 'SENTENCE...
# 1  Succinctly rephrase and simplify the 'SENTENCE...
# 2  Succinctly rephrase and simplify the 'SENTENCE...
# 3  Succinctly rephrase and simplify the 'SENTENCE...
# 4  Succinctly rephrase and simplify the 'SENTENCE...
#
#                                       Generated_Text  \
# 0  REPHRASED SENTENCE:  This policy explains what...
# 1  REPHRASED SENTENCE: Please read our privacy po...
# 2  REPHRASED SENTENCE: By using our app or other ...
# 3  REPHRASED SENTENCE:  We update this privacy po...
# 4  REPHRASED SENTENCE: Please review our privacy ...
#
#                                    Clean_Gen_Segment
# 0  This policy explains what data we collect, how...
# 1  Please read our privacy policy when using our ...
# 2  By using our app or other online services, you...
# 3  We update this privacy policy when changes are...
# 4        Please review our privacy policy regularly.

# %%
# Convert results to DataFrame
results_df_train = cleaned_results_train.to_pandas()

# Create a dictionary to map original segments to their simplified versions
simplified_map = dict(zip(results_df_train['Segment'], results_df_train['Clean_Gen_Segment']))

# Map the simplified texts back to the original dataframe
df_train['Simplified_Segment'] = df_train['Segment'].map(simplified_map)

# Define the path to save the modified file
output_path_train = '/content/drive/My Drive/w266-personal/Final Project/PLUE/data/privacyqa/policy_train_data_modified_loose.csv'

# Save the DataFrame back to a CSV file
df_train.to_csv(output_path_train, sep='\t', index=False)

# %%
# Convert results to DataFrame
results_df_test = cleaned_results_test.to_pandas()

# Create a dictionary to map original segments to their simplified versions
simplified_map_test = dict(zip(results_df_test['Segment'], results_df_test['Clean_Gen_Segment']))

# Map the simplified texts back to the original dataframe
df_test['Simplified_Segment'] = df_test['Segment'].map(simplified_map_test)

# Define the path to save the modified file
output_path_test = '/content/drive/My Drive/w266-personal/Final Project/PLUE/data/privacyqa/policy_test_data_modified_loose.csv'

# Save the DataFrame back to a CSV file
df_test.to_csv(output_path_test, sep='\t', index=False)
